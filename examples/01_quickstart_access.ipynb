# %% [markdown]
# # 01 · Quickstart: connecting to the project bucket
#
# Before running: copy `.env.example` to `.env` and paste in your read-only key.
# Your key is **read-only** and scoped to `nffcfirstteamstudents`.

# %%
import nffc_data as nffc

# %% [markdown]
# ## What's in the bucket?

# %%
nffc.list_bucket(depth=2)

# %% [markdown]
# ## Flat listing of one prefix

# %%
nffc.ls("Statsbomb/Premier League/2023-2024")

# %% [markdown]
# ## Read a parquet file

# %%
matches = nffc.load_parquet("Statsbomb/Premier League/2023-2024/matches.parquet")
print(matches.shape)
matches.head()

# %% [markdown]
# That's it — see the other notebooks for each dataset.
